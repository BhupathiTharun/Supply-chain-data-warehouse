# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
orders=pd.read_csv(r"D:\Data Analyst\EXCEL\supplychain\FACT_ORDERS.csv")
orders.head()
# Out:
#   order_line_id    order_id     date_id  order_date customer_id  product_id  \
# 0    OL00000001  ORD0210788  2026-02-20  2026-02-20  CUST009513  PROD000763
# 1    OL00000002  ORD0248321  2025-12-02  2025-12-02  CUST003412  PROD000142
# 2    OL00000003  ORD0377603  2025-04-03  2025-04-03  CUST065509  PROD001194
# 3    OL00000004  ORD0019414  2025-06-01  2025-06-01  CUST070677  PROD000221
# 4    OL00000005  ORD0157859  2025-10-25  2025-10-25  CUST017845  PROD000806
#
#    category seller_id  seller_rating location_id  ... return_date  \
# 0      Baby  SELL2379            4.6     LOC0010  ...         NaN
# 1  Clothing  SELL2964            4.0     LOC0053  ...         NaN
# 2    Gaming  SELL2485            3.9     LOC0095  ...         NaN
# 3      Home  SELL4121            4.0     LOC0038  ...         NaN
# 4      Pets  SELL3183            4.5     LOC0109  ...         NaN
#
#   customer_rating                            review_text sentiment_score  \
# ...

# %%
orders.shape
# Out:
# (790732, 35)

# %%
od=orders.copy()

# %% [markdown]
# - Shape	Number of rows and columns
# - Columns	Available fields
# - Head	Sample records
# - Info	Data types and null values
# - Describe	Numeric summary
# - Duplicates	Duplicate records
# - Missing Values	Null counts
# - Unique Values	Category counts

# %% [markdown]
# ## Step 4: Create a Data Dictionary
# - This is a professional practice.
# - Create a Markdown table like:
# - Column	Data Type	Description
# - Order_ID	Integer	Unique order identifier
# - Customer_ID	Integer	Customer reference
# - Product_ID	Integer	Product reference
# - Quantity	Integer	Number of items ordered
# - Sales	Float	Revenue from the order
# - Do this for every important table.

# %% [markdown]
# ## Step 6: Data Quality Assessment
# - Instead of jumping into cleaning, create a checklist.
# - Check	Status
# - Missing Values	Yes
# - Duplicate Rows	No
# - Incorrect Data Types	Yes
# - Negative Quantities	No
# - Future Dates	Yes
# - Invalid Categories	No
# - This gives you a roadmap for cleaning.

# %% [markdown]
# ## Step 7: Cleaning Plan
# ### Write your plan in Markdown.
#
# - Cleaning Plan
# 1. Remove duplicate records.
# 2. Convert date columns.
# 3. Handle missing values.
# 4. Standardize category names.
# 5. Remove impossible values.
# 6. Detect outliers.
# 7. Merge related datasets.
# 8. Save cleaned dataset.

# %%
# Step 8: Start Cleaning
# Now perform cleaning in this order:
# 1. Remove Duplicates

# df = df.drop_duplicates()

# 2. Fix Data Types

# df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# 3. Handle Missing Values
# Don't immediately fill everything.
# First inspect:

# df.isnull().sum()
# Then decide:
# 	• Drop? 
# 	• Fill with mean? 
# 	• Median? 
# 	• Mode? 
# 	• Business rule? 
# Explain why you chose that method.

# 4. Standardize Text
# Example:

# df["City"] = df["City"].str.title().str.strip()

# 5. Detect Outliers
# Use:

# sns.boxplot()
# IQR Method
# Z-score (if appropriate)
# Decide whether to keep or remove them based on business context.

# %% [markdown]
# # 6. Feature Engineering
# ### Create useful columns such as:
# - Profit
# - Profit Margin
# - Delivery Days
# - Order Month
# - Order Quarter
# - Order Year
# - Shipping Delay
